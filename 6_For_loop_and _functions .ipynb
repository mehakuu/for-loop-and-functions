# %%
for i in range(1, 8):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for i in range(1, 8, 2):
    print(i)
print("this is not a part of for loop")
# Out:
# 1
# 3
# 5
# 7
# this is not a part of for loop

# %%
for i in range(1,15,2):
    print(i)
else:
    print("This is inside else of for")
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
# 13
# This is inside else of for

# %%
for i in range(10):
    print(i)
    if i == 5:
        break
else:
    print("This is inside else of for")
print("hi")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# hi

# %%
l=[2,5,4]
for i in l:
    print(i)
# Out:
# 2
# 5
# 4

# %%
l=[2,5,4]
for i in l:
    print(i)
else:
    print("Done")
# Out:
# 2
# 5
# 4
# Done

# %%
for i in range(10):
    if i == 5:
        continue   #skip the iteration when i reaches 5
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
l1= [1,5,2]
for i in l1:
    pass

# %%
l1 = ["Harry", "Sohan", "Sachin", "Rahul"]
# say good morning to each member of the list ex: Good Morning, Harry 
#for i in l1:
#    print("Good Morning "+ i)

greeting ="good morning"

for i in range(4):
    print(greeting,l1[i],".")
# Out:
# good morning Harry .
# good morning Sohan .
# good morning Sachin .
# good morning Rahul .

# %%
greeting ="good morning"

for i in range(4):
    print(greeting,l1[i], end = "***")
# Out:
# good morning Harry***good morning Sohan***good morning Sachin***good morning Rahul***

# %%
l1 = ["Harry", "Sohan", "Sachin", "Rahul"]
#print alternative elements of the list eg: 2,4,6,8
for i in range(0,len(l1),2):
    print(l1[i])
# Out:
# Harry
# Sachin
